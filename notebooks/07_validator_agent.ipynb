# %% [markdown]
# # Validator Agent Notebook
#
# This notebook demonstrates the Validator Agent for code validation.
#
# ## Purpose
# - Test code validation
# - Run circuit simulations
# - Evaluate validation metrics
# - Test error detection
#
# ## Usage
# Import ValidatorAgent from src.agents.validator and validate generated code.
