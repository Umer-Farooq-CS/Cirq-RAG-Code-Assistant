# %% [markdown]
# # Educational Agent Notebook
#
# This notebook demonstrates the Educational Agent for generating explanations.
#
# ## Purpose
# - Test explanation generation
# - Create educational content
# - Generate visualizations
# - Test different explanation levels
#
# ## Usage
# Import EducationalAgent from src.agents.educational and generate explanations.
